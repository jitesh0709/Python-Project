# %%
# for importing data from csv file to here
import pandas as pd    
df= pd.read_csv('netflix1.csv')

# %%
df.shape
# will tell you how many number of rows and colmns are there
# Out:
# (8790, 10)

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
# return a sample number of 10 rows 
df.sample(n=10)
# Out:
#      show_id     type                                            title  \
# 8738   s8491  TV Show                              The Road to Calvary
# 7342   s2875  TV Show                                   Altered Carbon
# 5892   s8027    Movie                                  Sinister Circle
# 2978   s4053    Movie                           BNK48: Girls Don't Cry
# 8427   s6651    Movie                                  Driven to Dance
# 7534   s3421  TV Show                                       Second 20s
# 3779   s5256    Movie                               Our Souls at Night
# 2283   s2866    Movie               Voulez-vous rire avec moi ce soir?
# 7423   s3107  TV Show                                    Lost in Space
# 3838   s5336    Movie  Baahubali 2: The Conclusion (Malayalam Version)
#
#                         director        country  date_added  release_year  \
# 8738                   Not Given         Russia    9/1/2018          2017
# ...

# %%
df["title"].unique()
# Out:
# array(['Dick Johnson Is Dead', 'Ganglands', 'Midnight Mass', ...,
#        'Zindagi Gulzar Hai', 'Yoko', 'YOM'], shape=(8787,), dtype=object)

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %%
df.count()
# Out:
# show_id         8790
# type            8790
# title           8790
# director        8790
# country         8790
# date_added      8790
# release_year    8790
# rating          8790
# duration        8790
# listed_in       8790
# dtype: int64

# %%
# for first 5 data we will use this for mmatplotlib library
# %matplotlib inline
import matplotlib.pyplot as plt

df['show_id'].value_counts().head(5).plot(kind='bar')
plt.show()

# %%
print(df.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
df['duration'].sum()
# Out:
# '90 min1 Season1 Season91 min125 min9 Seasons104 min87 min127 min76 min76 min71 min131 min39 min36 min34 min35 min1 Season1 Season46 min1 Season1 Season1 Season91 min1 Season67 min65 min1 Season61 min166 min103 min97 min106 min1 Season1 Season1 Season1 Season2 Seasons1 Season1 Season2 Seasons4 Seasons2 Seasons1 Season1 Season1 Season1 Season2 Seasons1 Season1 Season1 Season147 min94 min161 min111 min110 min105 min96 min1 Season106 min124 min116 min98 min91 min115 min122 min55 min1 Season99 min99 min88 min100 min1 Season6 Seasons1 Season3 Seasons1 Season1 Season1 Season1 Season23 min102 min93 min96 min95 min85 min97 min95 min83 min1 Season1 Season1 Season1 Season1 Season3 Seasons182 min1 Season5 Seasons1 Season1 Season1 Season1 Season1 Season1 Season1 Season1 Season106 min147 min87 min1 Season85 min95 min92 min1 Season90 min84 min1 Season1 Season1 Season1 Season1 Season1 Season1 Season1 Season3 Seasons1 Season97 min1 Season48 min93 min145 min145 min96 min91 min119 min97 min110 min1 Se
# ...
